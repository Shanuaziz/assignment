# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
data=sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# The columns in the dataset

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.shape[1]
# Out:
# 5

# %% [markdown]
# mean of each column of the dataset

# %%
data.mean()
# Out:
# C:\Users\91894\AppData\Local\Temp\ipykernel_13980\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
data[data.isna()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             NaN          NaN           NaN          NaN     NaN
# 1             NaN          NaN           NaN          NaN     NaN
# 2             NaN          NaN           NaN          NaN     NaN
# 3             NaN          NaN           NaN          NaN     NaN
# 4             NaN          NaN           NaN          NaN     NaN
# ..            ...          ...           ...          ...     ...
# 145           NaN          NaN           NaN          NaN     NaN
# 146           NaN          NaN           NaN          NaN     NaN
# 147           NaN          NaN           NaN          NaN     NaN
# 148           NaN          NaN           NaN          NaN     NaN
# 149           NaN          NaN           NaN          NaN     NaN
#
# [150 rows x 5 columns]

# %% [markdown]
#  visualizations using the dataset.

# %%
print(data.sepal_length.value_counts())
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal_length, dtype: int64

# %%
sns.countplot(x='sepal_length',data=data,hue='species',palette='viridis')
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
sns.lineplot(x='sepal_length',y='petal_length',data=data,hue='species',palette='viridis')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.violinplot(data.sepal_width)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data.corr(),annot=True)
# Out:
# C:\Users\91894\AppData\Local\Temp\ipykernel_19008\2317824295.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=data.corr(),annot=True)
# <Axes: >
